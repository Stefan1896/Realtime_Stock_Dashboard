# %%
# %%sql
#
# CREATE OR REPLACE TABLE dim_ticker (
#   ticker STRING,
#   name   STRING
# );
#
# INSERT OVERWRITE TABLE dim_ticker
# VALUES
#   ('AAPL',  'Apple Inc.'),
#   ('MSFT',  'Microsoft Corporation'),
#   ('GOOGL', 'Alphabet Inc. (Class A)'),
#   ('AMZN',  'Amazon.com, Inc.'),
#   ('TSLA',  'Tesla, Inc.');
# Out:
# StatementMeta(, 5adfb9e7-7b6a-47ed-9e3c-3712a15a659f, 3, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
